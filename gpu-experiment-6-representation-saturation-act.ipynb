# %% [markdown]
# # GPU Experiment 6: Representation Saturation & Activation Drift Diagnostics
#
# This notebook empirically investigates the representation saturation hypothesis by tracking activation L2 norms $\|h_8^{(t)}\|_2$ and cosine similarity drift $\cos(h_8^{(t)}, h_8^{(0)})$ across generation steps $t \in [1, 200]$ for:
# 1. **Unsteered Baseline**
# 2. **Continuous Steering ($K=\infty, \alpha_0=18.0$)**
# 3. **Hard Cutoff Steering ($K=16, \alpha_0=18.0$)**
# 4. **Linear Decay Steering ($K=16, \alpha_0=18.0$)**

# %%
# !pip install -q evaluate bert_score bitsandbytes accelerate transformers

import os, sys, json, time, math, torch
import numpy as np
import torch.nn.functional as F
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Device 0: {torch.cuda.get_device_name(0)}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 MB 48.7 MB/s eta 0:00:00
# PyTorch Version: 2.10.0+cu128
# CUDA Available: True
# GPU Device 0: Tesla T4

# %%
possible_paths = [
    '/kaggle/input/datasets/trungkiennnn/vnese-data/vietnamese_medical_halueval_15k_specialized.json',
    '/kaggle/input/vietnamese-medical-halueval-15k/vietnamese_medical_halueval_15k_specialized.json',
    'e:/Paper_Steering_VN_15K/data/vietnamese_medical_halueval_15k_specialized.json',
    './data/vietnamese_medical_halueval_15k_specialized.json'
]

data_path = None
for p in possible_paths:
    if os.path.exists(p):
        data_path = p
        break

with open(data_path, 'r', encoding='utf-8') as f:
    full_dataset = json.load(f)

test_subset = full_dataset[-100:]  # N=100 subset for high-resolution diagnostic tracking
train_pool = full_dataset[:-2205]

model_id = "Qwen/Qwen2.5-7B-Instruct"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True, bnb_4bit_quant_type="nf4", bnb_4bit_compute_dtype=torch.float16, bnb_4bit_use_double_quant=True
)
tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
if tokenizer.pad_token is None: tokenizer.pad_token = tokenizer.eos_token
model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, device_map="auto", trust_remote_code=True)
model.eval()
print("✅ Model loaded for diagnostic tracking!")
# Out:
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# ✅ Model loaded for diagnostic tracking!

# %%
pos_acts, neg_acts = [], []
for item in train_pool[:150]:
    q = item['question']
    pos_ans = item.get('right_answer', item.get('positive_answer'))
    neg_ans = item['hallucinated_answer']
    
    t_pos = f"<|im_start|>user\n{q}<|im_end|>\n<|im_start|>assistant\n{pos_ans}"
    t_neg = f"<|im_start|>user\n{q}<|im_end|>\n<|im_start|>assistant\n{neg_ans}"
    
    with torch.no_grad():
        inp_pos = tokenizer(t_pos, return_tensors="pt").to(model.device)
        out_pos = model(inp_pos.input_ids, output_hidden_states=True)
        pos_acts.append(out_pos.hidden_states[8][0, -1, :].detach().cpu())
        
        inp_neg = tokenizer(t_neg, return_tensors="pt").to(model.device)
        out_neg = model(inp_neg.input_ids, output_hidden_states=True)
        neg_acts.append(out_neg.hidden_states[8][0, -1, :].detach().cpu())

v_diff = torch.stack(pos_acts).mean(dim=0) - torch.stack(neg_acts).mean(dim=0)
v_steer = v_diff / v_diff.norm(p=2)
print("✅ Vector v_steer extracted!")
# Out:
# ✅ Vector v_steer extracted!

# %%
target_layer = model.model.layers[8]

def run_diagnostic_tracking(schedule_type="decay", alpha_0=18.0, K=16):
    l2_norms_per_step = [[] for _ in range(100)]  # 100 max new tokens
    
    for item in tqdm(test_subset, desc=f"Tracking {schedule_type}"):
        prompt = f"<|im_start|>user\n{item['question']}<|im_end|>\n<|im_start|>assistant\n"
        inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
        
        step_counter = 0
        step_norms = []
        
        def track_hook(module, input_tensor, output_tensor):
            nonlocal step_counter
            step_counter += 1
            cur_t = output_tensor[0] if isinstance(output_tensor, tuple) else output_tensor
            
            if schedule_type == "continuous":
                alpha_t = alpha_0
            elif schedule_type == "cutoff":
                alpha_t = alpha_0 if step_counter <= K else 0.0
            elif schedule_type == "decay":
                alpha_t = alpha_0 * (1.0 - (step_counter - 1) / K) if 1 <= step_counter <= K else 0.0
            else:
                alpha_t = 0.0
                
            if alpha_t != 0.0:
                v_curr = v_steer.to(device=cur_t.device, dtype=cur_t.dtype)
                cur_t = cur_t + alpha_t * v_curr
                
            norm_val = float(cur_t[0, -1, :].norm(p=2).detach().cpu())
            step_norms.append(norm_val)
            
            if isinstance(output_tensor, tuple):
                return (cur_t,) + output_tensor[1:]
            return cur_t
            
        hook = target_layer.register_forward_hook(track_hook)
        with torch.no_grad():
            model.generate(**inputs, max_new_tokens=100, do_sample=False, pad_token_id=tokenizer.pad_token_id)
        hook.remove()
        
        for s_idx, nv in enumerate(step_norms[:100]):
            l2_norms_per_step[s_idx].append(nv)
            
    mean_norms = [float(np.mean(l2_norms_per_step[t])) if len(l2_norms_per_step[t]) > 0 else 0.0 for t in range(100)]
    return mean_norms

schedules = ["baseline", "continuous", "cutoff", "decay"]
diagnostic_results = {}

for s in schedules:
    diagnostic_results[s] = run_diagnostic_tracking(schedule_type=s)
    print(f"Completed tracking {s}: Mean Norm at t=10 is {diagnostic_results[s][10]:.2f}, at t=50 is {diagnostic_results[s][50]:.2f}")
# Out:
# Tracking baseline:   0%|          | 0/100 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#
# Tracking baseline:   1%|          | 1/100 [00:08<14:09,  8.58s/it]
# Tracking baseline:   2%|▏         | 2/100 [00:12<09:16,  5.68s/it]
# Tracking baseline:   3%|▎         | 3/100 [00:20<11:01,  6.82s/it]
# Tracking baseline:   4%|▍         | 4/100 [00:28<11:44,  7.34s/it]
# Tracking baseline:   5%|▌         | 5/100 [00:32<09:32,  6.02s/it]
# Tracking baseline:   6%|▌         | 6/100 [00:40<10:35,  6.76s/it]
# Tracking baseline:   7%|▋         | 7/100 [00:48<11:06,  7.16s/it]
# Tracking baseline:   8%|▊         | 8/100 [00:56<11:28,  7.48s/it]
# Tracking baseline:   9%|▉         | 9/100 [01:04<11:43,  7.73s/it]
# Tracking baseline:  10%|█         | 10/100 [01:12<11:46,  7.86s/it]
# Tracking baseline:  11%|█         | 11/100 [01:21<11:45,  7.92s/it]
# Tracking baseline:  12%|█▏        | 12/100 [01:29<11:40,  7.96s/it]
# Tracking baseline:  13%|█▎        | 13/100 [01:37<11:35,  8.00s/it]
# Tracking baseline:  86%|████████▌ | 86/100 [11:15<02:02,  8.77s/it]
# Tracking baseline:  87%|████████▋ | 87/100 [11:24<01:54,  8.84s/it]
# Tracking baseline:  88%|████████▊ | 88/100 [11:33<01:46,  8.87s/it]
# Tracking baseline:  89%|████████▉ | 89/100 [11:37<01:21,  7.40s/it]
# Tracking baseline:  90%|█████████ | 90/100 [11:46<01:18,  7.87s/it]
# Tracking baseline:  91%|█████████ | 91/100 [11:55<01:13,  8.20s/it]
# Tracking baseline:  92%|█████████▏| 92/100 [12:04<01:07,  8.43s/it]
# Tracking baseline:  93%|█████████▎| 93/100 [12:13<01:00,  8.61s/it]
# Tracking baseline:  94%|█████████▍| 94/100 [12:22<00:52,  8.70s/it]
# Tracking baseline:  95%|█████████▌| 95/100 [12:31<00:43,  8.77s/it]
# Tracking baseline:  96%|█████████▌| 96/100 [12:40<00:35,  8.84s/it]
# Tracking baseline:  97%|█████████▋| 97/100 [12:49<00:26,  8.84s/it]
# Tracking baseline:  98%|█████████▊| 98/100 [12:58<00:17,  8.88s/it]
# Tracking baseline:  99%|█████████▉| 99/100 [13:07<00:08,  8.88s/it]
# Tracking baseline: 100%|██████████| 100/100 [13:15<00:00,  7.96s/it]
# Completed tracking baseline: Mean Norm at t=10 is 53.64, at t=50 is 52.20
# Tracking continuous:   0%|          | 0/100 [00:00<?, ?it/s]
# Tracking continuous:   1%|          | 1/100 [00:08<14:43,  8.93s/it]
# Tracking continuous:   2%|▏         | 2/100 [00:17<14:31,  8.89s/it]
# Tracking continuous:   3%|▎         | 3/100 [00:26<14:18,  8.85s/it]
# Tracking continuous:   4%|▍         | 4/100 [00:35<14:10,  8.86s/it]
# Tracking continuous:   5%|▌         | 5/100 [00:44<14:02,  8.87s/it]
# Tracking continuous:   6%|▌         | 6/100 [00:53<13:55,  8.89s/it]
# Tracking continuous:   7%|▋         | 7/100 [01:02<13:45,  8.87s/it]
# Tracking continuous:   8%|▊         | 8/100 [01:10<13:35,  8.86s/it]
# Tracking continuous:   9%|▉         | 9/100 [01:19<13:23,  8.83s/it]
# Tracking continuous:  10%|█         | 10/100 [01:28<13:18,  8.87s/it]
# Tracking continuous:  11%|█         | 11/100 [01:37<13:10,  8.88s/it]
# Tracking continuous:  12%|█▏        | 12/100 [01:46<13:03,  8.90s/it]
# Tracking continuous:  13%|█▎        | 13/100 [01:55<12:54,  8.90s/it]
# Tracking continuous:  14%|█▍        | 14/100 [02:04<12:42,  8.87s/it]
# Tracking continuous:  15%|█▌        | 15/100 [02:13<12:34,  8.87s/it]
# Tracking continuous:  16%|█▌        | 16/100 [02:21<12:23,  8.85s/it]
# Tracking continuous:  17%|█▋        | 17/100 [02:30<12:15,  8.86s/it]
# Tracking continuous:  18%|█▊        | 18/100 [02:39<12:04,  8.83s/it]
# Tracking continuous:  19%|█▉        | 19/100 [02:48<11:55,  8.83s/it]
# Tracking continuous:  20%|██        | 20/100 [02:57<11:43,  8.80s/it]
# Tracking continuous:  57%|█████▋    | 57/100 [08:19<06:16,  8.75s/it]
# Tracking continuous:  58%|█████▊    | 58/100 [08:28<06:08,  8.76s/it]
# Tracking continuous:  59%|█████▉    | 59/100 [08:37<05:59,  8.77s/it]
# Tracking continuous:  60%|██████    | 60/100 [08:45<05:50,  8.76s/it]
# Tracking continuous:  61%|██████    | 61/100 [08:54<05:41,  8.76s/it]
# Tracking continuous:  62%|██████▏   | 62/100 [09:03<05:32,  8.76s/it]
# Tracking continuous:  63%|██████▎   | 63/100 [09:11<05:23,  8.74s/it]
# Tracking continuous:  64%|██████▍   | 64/100 [09:20<05:13,  8.70s/it]
# Tracking continuous:  65%|██████▌   | 65/100 [09:29<05:04,  8.70s/it]
# Tracking continuous:  66%|██████▌   | 66/100 [09:37<04:55,  8.68s/it]
# Tracking continuous:  67%|██████▋   | 67/100 [09:46<04:46,  8.67s/it]
# Tracking continuous:  68%|██████▊   | 68/100 [09:55<04:37,  8.66s/it]
# Tracking continuous:  69%|██████▉   | 69/100 [10:03<04:27,  8.64s/it]
# Tracking continuous:  70%|███████   | 70/100 [10:12<04:18,  8.60s/it]
# Tracking continuous:  71%|███████   | 71/100 [10:20<04:09,  8.60s/it]
# Tracking continuous:  72%|███████▏  | 72/100 [10:29<04:01,  8.62s/it]
# Tracking continuous:  73%|███████▎  | 73/100 [10:38<03:53,  8.65s/it]
# Tracking continuous:  74%|███████▍  | 74/100 [10:47<03:46,  8.69s/it]
# Tracking continuous:  75%|███████▌  | 75/100 [10:55<03:37,  8.72s/it]
# Tracking continuous:  76%|███████▌  | 76/100 [11:04<03:28,  8.70s/it]
# Tracking continuous:  77%|███████▋  | 77/100 [11:13<03:19,  8.65s/it]
# Tracking continuous:  78%|███████▊  | 78/100 [11:21<03:10,  8.64s/it]
# Tracking continuous:  79%|███████▉  | 79/100 [11:30<03:02,  8.68s/it]
# Tracking continuous:  80%|████████  | 80/100 [11:39<02:53,  8.69s/it]
# Tracking continuous:  81%|████████  | 81/100 [11:47<02:45,  8.73s/it]
# Tracking continuous:  82%|████████▏ | 82/100 [11:56<02:36,  8.70s/it]
# Tracking continuous:  83%|████████▎ | 83/100 [12:05<02:27,  8.69s/it]
# Tracking continuous:  84%|████████▍ | 84/100 [12:14<02:19,  8.72s/it]
# Tracking continuous:  85%|████████▌ | 85/100 [12:22<02:11,  8.78s/it]
# Tracking continuous:  86%|████████▌ | 86/100 [12:31<02:03,  8.81s/it]
# Tracking continuous:  87%|████████▋ | 87/100 [12:40<01:54,  8.81s/it]
# Tracking continuous:  88%|████████▊ | 88/100 [12:49<01:45,  8.81s/it]
# Tracking continuous:  89%|████████▉ | 89/100 [12:58<01:36,  8.79s/it]
# Tracking continuous:  90%|█████████ | 90/100 [13:07<01:27,  8.79s/it]
# Tracking continuous:  91%|█████████ | 91/100 [13:15<01:18,  8.78s/it]
# Tracking continuous:  92%|█████████▏| 92/100 [13:24<01:10,  8.78s/it]
# Tracking continuous:  93%|█████████▎| 93/100 [13:33<01:01,  8.80s/it]
# Tracking continuous:  94%|█████████▍| 94/100 [13:42<00:53,  8.86s/it]
# Tracking continuous:  95%|█████████▌| 95/100 [13:51<00:44,  8.83s/it]
# Tracking continuous:  96%|█████████▌| 96/100 [13:59<00:35,  8.83s/it]
# Tracking continuous:  97%|█████████▋| 97/100 [14:08<00:26,  8.80s/it]
# Tracking continuous:  98%|█████████▊| 98/100 [14:17<00:17,  8.77s/it]
# Tracking continuous:  99%|█████████▉| 99/100 [14:26<00:08,  8.74s/it]
# Tracking continuous: 100%|██████████| 100/100 [14:34<00:00,  8.75s/it]
# Completed tracking continuous: Mean Norm at t=10 is 56.28, at t=50 is 55.13
# Tracking cutoff:   0%|          | 0/100 [00:00<?, ?it/s]
# Tracking cutoff:   1%|          | 1/100 [00:08<14:29,  8.79s/it]
# Tracking cutoff:   2%|▏         | 2/100 [00:17<14:15,  8.73s/it]
# Tracking cutoff:   3%|▎         | 3/100 [00:26<14:05,  8.72s/it]
# Tracking cutoff:   4%|▍         | 4/100 [00:34<14:00,  8.75s/it]
# Tracking cutoff:   5%|▌         | 5/100 [00:43<13:50,  8.75s/it]
# Tracking cutoff:   6%|▌         | 6/100 [00:52<13:40,  8.73s/it]
# Tracking cutoff:   7%|▋         | 7/100 [01:01<13:32,  8.74s/it]
# Tracking cutoff:   8%|▊         | 8/100 [01:09<13:25,  8.76s/it]
# Tracking cutoff:   9%|▉         | 9/100 [01:18<13:18,  8.78s/it]
# Tracking cutoff:  10%|█         | 10/100 [01:27<13:08,  8.76s/it]
# Tracking cutoff:  11%|█         | 11/100 [01:36<12:58,  8.75s/it]
# Tracking cutoff:  12%|█▏        | 12/100 [01:45<12:50,  8.75s/it]
# Tracking cutoff:  13%|█▎        | 13/100 [01:48<10:35,  7.31s/it]
# Tracking cutoff:  14%|█▍        | 14/100 [01:57<11:05,  7.74s/it]
# Tracking cutoff:  15%|█▌        | 15/100 [02:06<11:22,  8.03s/it]
# Tracking cutoff:  16%|█▌        | 16/100 [02:15<11:30,  8.22s/it]
# Tracking cutoff:  17%|█▋        | 17/100 [02:23<11:33,  8.35s/it]
# Tracking cutoff:  18%|█▊        | 18/100 [02:32<11:30,  8.42s/it]
# Tracking cutoff:  19%|█▉        | 19/100 [02:41<11:32,  8.55s/it]
# Tracking cutoff:  20%|██        | 20/100 [02:49<11:29,  8.62s/it]
# Tracking cutoff:  21%|██        | 21/100 [02:58<11:22,  8.64s/it]
# Tracking cutoff:  22%|██▏       | 22/100 [03:07<11:17,  8.69s/it]
# Tracking cutoff:  23%|██▎       | 23/100 [03:16<11:09,  8.69s/it]
# Tracking cutoff:  24%|██▍       | 24/100 [03:24<11:02,  8.72s/it]
# Tracking cutoff:  25%|██▌       | 25/100 [03:33<10:53,  8.72s/it]
# Tracking cutoff:  96%|█████████▌| 96/100 [13:49<00:35,  8.83s/it]
# Tracking cutoff:  97%|█████████▋| 97/100 [13:58<00:26,  8.92s/it]
# Tracking cutoff:  98%|█████████▊| 98/100 [14:07<00:17,  8.90s/it]
# Tracking cutoff:  99%|█████████▉| 99/100 [14:16<00:08,  8.87s/it]
# Tracking cutoff: 100%|██████████| 100/100 [14:25<00:00,  8.65s/it]
# Completed tracking cutoff: Mean Norm at t=10 is 56.28, at t=50 is 52.75
# Tracking decay:   0%|          | 0/100 [00:00<?, ?it/s]
# Tracking decay:   1%|          | 1/100 [00:08<14:28,  8.78s/it]
# Tracking decay:   2%|▏         | 2/100 [00:17<14:23,  8.81s/it]
# Tracking decay:   3%|▎         | 3/100 [00:26<14:09,  8.76s/it]
# Tracking decay:   4%|▍         | 4/100 [00:31<11:29,  7.18s/it]
# Tracking decay:   5%|▌         | 5/100 [00:39<12:15,  7.74s/it]
# Tracking decay:   6%|▌         | 6/100 [00:48<12:41,  8.10s/it]
# Tracking decay:   7%|▋         | 7/100 [00:53<10:52,  7.02s/it]
# Tracking decay:   8%|▊         | 8/100 [01:02<11:36,  7.57s/it]
# Tracking decay:   9%|▉         | 9/100 [01:10<12:01,  7.93s/it]
# Tracking decay:  10%|█         | 10/100 [01:19<12:14,  8.17s/it]
# Tracking decay:  11%|█         | 11/100 [01:28<12:22,  8.34s/it]
# Tracking decay:  12%|█▏        | 12/100 [01:36<12:23,  8.44s/it]
# Tracking decay:  13%|█▎        | 13/100 [01:41<10:40,  7.37s/it]
# Tracking decay:  14%|█▍        | 14/100 [01:50<11:09,  7.78s/it]
# Tracking decay:  15%|█▌        | 15/100 [01:59<11:26,  8.07s/it]
# Tracking decay:  16%|█▌        | 16/100 [02:08<11:33,  8.26s/it]
# Tracking decay:  17%|█▋        | 17/100 [02:16<11:38,  8.41s/it]
# Tracking decay:  18%|█▊        | 18/100 [02:25<11:38,  8.52s/it]
# Tracking decay:  19%|█▉        | 19/100 [02:34<11:34,  8.57s/it]
# Tracking decay:  20%|██        | 20/100 [02:43<11:29,  8.62s/it]
# Tracking decay:  21%|██        | 21/100 [02:51<11:24,  8.66s/it]
# Tracking decay:  22%|██▏       | 22/100 [03:00<11:17,  8.69s/it]
# Tracking decay:  23%|██▎       | 23/100 [03:09<11:08,  8.68s/it]
# Tracking decay:  24%|██▍       | 24/100 [03:17<11:01,  8.70s/it]
# Tracking decay:  25%|██▌       | 25/100 [03:22<09:26,  7.55s/it]
# Tracking decay:  26%|██▌       | 26/100 [03:31<09:43,  7.89s/it]
# Tracking decay:  27%|██▋       | 27/100 [03:40<09:54,  8.15s/it]
# Tracking decay:  28%|██▊       | 28/100 [03:48<09:57,  8.30s/it]
# Tracking decay:  29%|██▉       | 29/100 [03:57<09:57,  8.42s/it]
# Tracking decay:  30%|███       | 30/100 [04:06<09:56,  8.53s/it]
# Tracking decay:  31%|███       | 31/100 [04:15<09:52,  8.58s/it]
# Tracking decay:  69%|██████▉   | 69/100 [09:39<04:23,  8.51s/it]
# Tracking decay:  70%|███████   | 70/100 [09:44<03:43,  7.44s/it]
# Tracking decay:  71%|███████   | 71/100 [09:53<03:47,  7.85s/it]
# Tracking decay:  72%|███████▏  | 72/100 [10:01<03:46,  8.10s/it]
# Tracking decay:  73%|███████▎  | 73/100 [10:10<03:43,  8.29s/it]
# Tracking decay:  74%|███████▍  | 74/100 [10:19<03:40,  8.47s/it]
# Tracking decay:  75%|███████▌  | 75/100 [10:28<03:34,  8.59s/it]
# Tracking decay:  76%|███████▌  | 76/100 [10:37<03:28,  8.69s/it]
# Tracking decay:  77%|███████▋  | 77/100 [10:46<03:20,  8.71s/it]
# Tracking decay:  78%|███████▊  | 78/100 [10:54<03:11,  8.72s/it]
# Tracking decay:  79%|███████▉  | 79/100 [10:59<02:37,  7.51s/it]
# Tracking decay:  80%|████████  | 80/100 [11:08<02:37,  7.89s/it]
# Tracking decay:  81%|████████  | 81/100 [11:17<02:34,  8.13s/it]
# Tracking decay:  82%|████████▏ | 82/100 [11:25<02:29,  8.31s/it]
# Tracking decay:  83%|████████▎ | 83/100 [11:34<02:22,  8.41s/it]
# Tracking decay:  84%|████████▍ | 84/100 [11:43<02:16,  8.51s/it]
# Tracking decay:  85%|████████▌ | 85/100 [11:51<02:08,  8.57s/it]
# Tracking decay:  86%|████████▌ | 86/100 [12:00<02:00,  8.61s/it]
# Tracking decay:  87%|████████▋ | 87/100 [12:09<01:52,  8.67s/it]
# Tracking decay:  88%|████████▊ | 88/100 [12:18<01:44,  8.68s/it]
# Tracking decay:  89%|████████▉ | 89/100 [12:26<01:35,  8.68s/it]
# Tracking decay:  90%|█████████ | 90/100 [12:35<01:26,  8.66s/it]
# Tracking decay:  91%|█████████ | 91/100 [12:40<01:07,  7.49s/it]
# Tracking decay:  92%|█████████▏| 92/100 [12:48<01:02,  7.83s/it]
# Tracking decay:  93%|█████████▎| 93/100 [12:57<00:56,  8.06s/it]
# Tracking decay:  94%|█████████▍| 94/100 [13:05<00:49,  8.22s/it]
# Tracking decay:  95%|█████████▌| 95/100 [13:14<00:41,  8.37s/it]
# Tracking decay:  96%|█████████▌| 96/100 [13:23<00:33,  8.47s/it]
# Tracking decay:  97%|█████████▋| 97/100 [13:32<00:25,  8.52s/it]
# Tracking decay:  98%|█████████▊| 98/100 [13:40<00:17,  8.59s/it]
# Tracking decay:  99%|█████████▉| 99/100 [13:49<00:08,  8.65s/it]
# Tracking decay: 100%|██████████| 100/100 [13:58<00:00,  8.38s/it]
# Completed tracking decay: Mean Norm at t=10 is 52.95, at t=50 is 52.39

# %%
with open("representation_saturation_diagnostics.json", "w", encoding="utf-8") as f:
    json.dump(diagnostic_results, f, indent=2, ensure_ascii=False)

print("✅ Saved representation_saturation_diagnostics.json successfully!")
# Out:
# ✅ Saved representation_saturation_diagnostics.json successfully!
